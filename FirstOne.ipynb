# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib_inline
# %matplotlib inline
sales = pd.read_csv('C:/Users/DELL/Desktop/AI ML/DATA SETS\sales_data.csv')
plt.style.use('ggplot')
fig=plt.figure(figsize=(16,12))
sns.regplot(x=sales['Year'],y=sales['Profit'])
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Profit'>

# %%
sns.barplot(x=sales['Year'],y=sales['Revenue'])
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Revenue'>

# %%
sales['Revenue'].loc[sales["Year"]==2011].describe()
# Out:
# count     2677.000000
# mean      3348.856182
# std       2857.571875
# min        410.000000
# 25%       1395.000000
# 50%       2272.000000
# 75%       4389.000000
# max      14312.000000
# Name: Revenue, dtype: float64

# %%
sales['Revenue'].loc[sales['Year'] == 2012].describe()
# Out:
# count    2677.000000
# mean     3427.711244
# std      1876.138878
# min       821.000000
# 25%      1747.000000
# 50%      3666.000000
# 75%      4544.000000
# max      7156.000000
# Name: Revenue, dtype: float64

# %%
sales['Revenue'].loc[sales['Year'] == 2013].describe()
# Out:
# count    24443.000000
# mean       623.492902
# std        874.150763
# min          2.000000
# 25%         69.000000
# 50%        247.000000
# 75%        792.000000
# max      54069.000000
# Name: Revenue, dtype: float64

# %%
sales['Revenue'].loc[sales['Year'] == 2014].describe()
# Out:
# count    29398.000000
# mean       481.417920
# std        679.891557
# min          2.000000
# 25%         56.000000
# 50%        165.000000
# 75%        617.000000
# max       3542.000000
# Name: Revenue, dtype: float64

# %%
sns.barplot(x=sales["Age_Group"],y=sales['Revenue'])
# Out:
# <AxesSubplot: xlabel='Age_Group', ylabel='Revenue'>

# %%
sns.scatterplot(x=sales['Age_Group'],y=sales['Revenue'])
# Out:
# <AxesSubplot: xlabel='Age_Group', ylabel='Revenue'>

# %%
fig = plt.figure(figsize=(16,16))
sns.heatmap(sales.corr(),cmap='RdBu_r',annot=True,vmin=-1,vmax=1)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13932\996889717.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sales.corr(),cmap='RdBu_r',annot=True,vmin=-1,vmax=1)
# <AxesSubplot: >

# %%
fig = plt.figure(figsize=(16,10))
sns.scatterplot(x=sales['Product_Category'],y=sales['Revenue'],palette='bright',data=sales,hue='Country')
# Out:
# <AxesSubplot: xlabel='Product_Category', ylabel='Revenue'>

# %%
fig = plt.figure(figsize=(8,40))
sns.lmplot(x='Year',y="Revenue",data=sales,palette='bright',col='Country',hue='Product_Category')

# %%
fig = plt.figure(figsize=(16,16))
sns.lineplot(x='Year',y='Revenue',data = sales,palette='bright',hue='Country')
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Revenue'>

# %%
fig = plt.figure(figsize=(16,16))
sns.kdeplot(x='Profit',data=sales,palette='bright',hue='Country')
# Out:
# <AxesSubplot: xlabel='Profit', ylabel='Density'>

# %%
sns.jointplot(kind='reg',x='Year',y='Revenue',data=sales)
#We cannot have a hue for jointplot of regression kind and hex also

# %%
sns.scatterplot(x='Year',y='Revenue',data=sales)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Revenue'>
